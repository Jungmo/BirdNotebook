# %%
import matplotlib

#matplotlib.use('Agg')
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# I0202 16:58:14.842052 10592 solver.cpp:404]     Test net output #1: loss1/top-1 = 0.0808

log = open("caffe.bin.gpuserver.jungmo.log.INFO.20170410-200337.25951", "r")

loss1_loss1 = []
loss2_loss1 = []
loss3_loss3 = []

t_loss1_loss1 = []
t_loss1_top_1 = []
t_loss1_top_5 = []
t_loss2_loss1 = []
t_loss2_top_1 = []
t_loss2_top_5 = []
t_loss3_loss3 = []
t_loss3_top_1 = []
t_loss3_top_5 = []

loss = []

while True:
    line = log.readline()
    if not line: break
    if line.find("Train net output #0: loss1/loss1 ") != -1 : #loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        loss1_loss1.append(value)
    elif line.find("Train net output #1: loss2/loss1") != -1 : #loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        loss2_loss1.append(value)
    elif line.find("Train net output #2: loss3/loss3") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        loss3_loss3.append(value)

    elif line.find("Test net output #0") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        t_loss1_loss1.append(value)
    elif line.find("Test net output #1") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss1_top_1.append(value)
    elif line.find("Test net output #2") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss1_top_5.append(value)
    elif line.find("Test net output #3") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        t_loss2_loss1.append(value)
    elif line.find("Test net output #4") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss2_top_1.append(value)
    elif line.find("Test net output #5") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss2_top_5.append(value)
    elif line.find("Test net output #6") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        split = value.split("(")
        value = split[0]
        value = float(value)
        t_loss3_loss3.append(value)
    elif line.find("Test net output #7") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss3_top_1.append(value)
    elif line.find("Test net output #8") != -1:  # loss1/top-1
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        t_loss3_top_5.append(value)
    elif line.find("100 iters), loss = ") != -1:
        split = line.split(" = ")
        value = split[1]
        value = float(value)
        loss.append(value)

print len(loss)
# Out:
# 1000

# %%
'''
red = mpatches.Patch(color='red', label = 'test_loss1_loss_1')
blue = mpatches.Patch(color='blue', label = 'test_loss2_top_1')
green = mpatches.Patch(color='green', label = 'test_loss3_top_1')
yellow = mpatches.Patch(color='yellow', label = 'train loss')

fig = plt.figure()
ax1 = fig.add_subplot(111)
ax2 = ax1.twiny()

ax1.plot(t_loss1_loss1,'r',t_loss2_top_1,'b',t_loss3_top_1,'g')
ax2.plot(loss,'y')
ax1.set_xlabel("epoch")
ax2.set_xlabel("iteration / 40")
plt.ylim(0, 10)
plt.legend(handles=[red,blue,green,yellow])
plt.ylabel("loss")
#fig.show()
#plt.savefig("fig.png")
#print t_loss3_top_1
'''

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(30, 20)
plt.plot(t_loss1_loss1,'r')
plt.ylim(-0.2, 10)
plt.show()

fig = matplotlib.pyplot.gcf()
plt.plot(loss,'g')
plt.ylim(-0.2, 10)
fig.set_size_inches(30, 20)
plt.show()
